# %%
import requests # selenium과 달리 내장되어있어서 따로 설치할 필요없음
from bs4 import BeautifulSoup
import time
import codecs

# %%
# 1. requests.get("접속주소")로 접속
res = requests.get("https://www.naver.com")
# 2. 받아온 변수 res.text를 하면 해당 페이지의 소스코드가 나옵니다.
source = res.text
source
# Out:
# '\n<!doctype html>                          <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta property="og:title" content="네이버"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/> <meta name="twitter:card" content="summary"> <meta name="twitter:title" content=""> <meta name="twitter:url" content="https://www.naver.com/"> <meta name="twitter:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta name="twitter:description" content="네이버 메인에서 다양한 정보와 유용한 컨텐츠를 만나 보세요"/>  <link rel="stylesheet" href="https://pm.pstatic.net/dist/css/nmain.20220720.css"> <link rel="stylesheet" href="https://ssl.pstatic.net/sstatic/search/pc/css/sp_autocomplete_220526.css"> <link rel="shortcut icon" type="image/x-icon" href="/favicon.ico?1"/>  <link rel="apple-touch-icon" sizes="114x114" href="https://s.pstatic.net/static/www/u/2014/0328/mma_204243574.png"/> <link rel="apple-touch-icon" href="https://s.pstatic.net/static/www/u/2014/0328/mma_20432863.png"/> <script>window.nmain=window.nmain||{},window.nmain.supportFlicking=!1;var nsc="navertop.v4",ua=navigator.userAgent,useIeJSFlag="1";window.nmain.isIE="0"===useIeJSFlag,document.getElementsByTagName("html")[0].setAttribute("data-useragent",ua),window.nmain.isIE&&(Object.create=function(n){function e(){}return e.prototype=n,new e})</script> <script>var darkmode= false;window.naver_corp_da=window.naver_corp_da||{main:{}},window.naver_corp_da.main=window.naver_corp_da.main||{},window.naver_corp_da.main.darkmode=darkmode,window.gladsdk=window.gladsdk||{cmd:[]},window.gladsdk.cmd.push((function(){window.gladsdk.setHostMeta("theme",darkmode?"dark":"light")})),window.ndpsdk=window.ndpsdk||{cmd:[],polyfill:{cmd:[]}},window.ndpsdk.cmd.push((function(){window.ndpsdk.setHostMeta("theme",darkmode?"dark":"light")}))</script>  <script async src="https://ssl.pstatic.net/tveta/libs/glad/prod/gfp-core.js"></script> <script async src="https://ssl.pstatic.net/tveta/libs/ndpsdk/prod/ndp-loader.js"></script>  <script> window.nmain.gv = {  isLogin: false,\nuseId: null,   daInfo: {"BEAUTY":{"menu":"BEAUTY","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000163","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_1","tb":"BEAUTY_1","unit":"SU10595","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000164","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_beauty_2","tb":"BEAUTY_1","unit":"SU10596","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVING":{"menu":"LIVING","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000183","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_1","tb":"LIVING_1","unit":"SU10597","calp":"-"},"type":{"position":"abs","positionIndex":4,"subject":"contents"},"dom":null},{"adposId":"1000184","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_living_2","tb":"LIVING_1","unit":"SU10606","calp":"-"},"type":{"position":"abs","positionIndex":8,"subject":"contents"},"dom":null}]},"LIVINGHOME":{"menu":"LIVINGHOME","childMenu":"","adType":"singleDom","multiDomAdUrl":"","multiDomUnit":"","infoList":[{"adposId":"1000185","singleDomAdUrl":"https://siape.veta.naver.com/fxshow","param":{"da_dom_id":"p_main_livinghome_1","tb":"L ...

# %%
# 위 내용을 토대로 교보문고 순회 크롤러를 이용해 1~200위까지의 도서 제목, 가격, 저자를 얻어와서
# txt나 csv파일로 만들어주세요.
# 전체 제목, 작가, 가격정보를 저장하기 위한 리스트 생성

# %%
# 각 항목들을 순차적으로 저장하기 위해 빈 리스트 선언
title_list = []
author_list = []
price_list = []

# %%
# 교보문고 순회 크롤러를 만들어주세요.
# 1~200위까지의 책을 txt파일로 저장해주시면 됩니다.
# 텍스트 파일저장
f = codecs.open("c:/crawler2/kyobo.txt", mode="w", encoding="utf-8")

for i in range(1, 5):
    time.sleep(3)
    # 해당 주소 접속 정보를 res에 저장
    res = requests.get("https://www.kyobobook.co.kr/bestSellerNew/bestseller.laf?targetPage=%s" % i)
    # res 변수에 저장된 소스코드만 뽑아서 source변수에 저장
    source = res.text

    bs = BeautifulSoup(source, "html.parser")

    # 리스트가 아닌 단 하나의 태그를 얻어옴
    ul_tag = bs.find("ul", class_="list_type01")
    # find는 리스트 형식으로 가져오지 않기 때문에, 인덱싱 없이 바로 추가 명령을 내릴 수 있습니다.
    title_tag_list = ul_tag.find_all("div", class_="title")
    author_tag_list = ul_tag.find_all("div", class_="author")
    price_tag_list = ul_tag.find_all("div", class_="price")

    for item in title_tag_list:
        title_list.append(item.text.strip().replace("\n","").replace("\t", ""))

    for item in author_tag_list:
        author_list.append(item.text.strip().replace("\n","").replace("\t", "").replace("\r", ""))

    for item in price_tag_list:
        price_list.append(item.text.strip().replace("\n","").replace("\t", "").replace("\r",""))
# title_tag_list에 200개의 요소가 들어있으므로 인덱스번호를 이용해 텍스트파일화
for i in range(len(title_list)):
    f.write("%s위 책 정보\n" % (i + 1))
    f.write(title_list[i] + "\n")
    f.write(author_list[i] + "\n")
    f.write(price_list[i] + "\n")
    f.write("--------------------\n")
f.close()

# %%
author_list
# Out:
# ['자청| 웅진지식하우스| 2022년 05월 30일',
#  '김호연| 나무옆의자| 2021년 04월 20일',
#  '무라세 다케시| 모모| 2022년 05월 09일',
#  '임은정| 메디치미디어| 2022년 07월 22일',
#  '김영하| 복복서가| 2022년 05월 02일',
#  '김다슬| 클라우디아| 2022년 04월 12일',
#  '히로시마 레이코| 길벗스쿨| 2022년 07월 11일',
#  '유시민| 생각의길| 2022년 07월 09일',
#  '황보름| 클레이하우스| 2022년 01월 17일',
#  '정한아| 문학동네| 2017년 10월 13일',
#  '장성락(REDICE STUDIO)저자 더보기추공 (원작)현군 (각색)| 디앤씨웹툰비즈| 2022년 07월 25일',
#  '오건영| 페이지2북스| 2022년 05월 23일',
#  '유대영| 아울북| 2022년 07월 12일',
#  '이연| 푸른숲| 2022년 07월 20일',
#  '레이 달리오| 한빛비즈| 2022년 06월 01일',
#  '장신웨| 리드리드출판| 2022년 08월 11일',
#  '이어령| 김영사| 2022년 06월 30일',
#  'David Cho| 해커스어학연구소| 2022년 03월 14일',
#  '최재천저자 더보기안희경| 김영사| 2022년 05월 18일',
#  '네모토 히로유키| 밀리언서재| 2022년 06월 24일',
#  '박세니| 마인드셋(Mindset)| 2022년 04월 30일',
#  '에그박사 (원작)저자 더보기박송이| 미래엔아이세움| 2022년 06월 15일',
#  '세이카 료겐| 모모| 2022년 05월 09일',
#  '황성주| 정민미디어| 2022년 07월 01일',
#  'AidaIro| 서울미디어코믹스(서울문화사)| 2022년 07월 30일',
#  '후이| 미디어숲| 2022년 08월 10일',
#  '훨훨(박성혜)| 다산북스| 2022년 07월 11일',
#  '이미예| 팩토리나인| 2020년 07월 08일',
#  '개러스 무어| 미디어숲| 2022년 07월 20일',
#  '로버트 기요사키| 민음인| 2018년 02월 22일',
#  '폴커 키츠저자 더보기마누엘 투쉬| 포레스트북스| 2022년 02월 10일',
#  'Eiichiro Oda| 대원씨아이| 2022년 06월 30일',
#  '흔한남매 (원작)저자 더보기백난도| 미래엔아이세움| 2022년 04월 28일',
#  '흔한남매 (원작)저자 더보기이현진닥터 스코| 주니어김영사| 2022년 06월 16일',
#  '룰루 밀러| 곰출판| 2021년 12월 17일',
#  '앤절라 더크워스| 비즈니스북스| 2019년 02월 20일',
#  '마리온 라부저자 더보기니콜라스 데프렌스| 미디어숲| 2022년 07월 07일',
#  'One (원작)| 대원씨아이| 2022년 07월 31일',
#  'B. A. 패리스| 모모| 2021년 12월 06일',
#  '대원키즈 편집부| 대원키즈| 2017년 10월 19일',
#  '손웅정| 수오서재| 2021년 10월 15일',
#  '영어독립단어 콘텐츠팀저자 더보기신미주| 상상스퀘어| 2022년 06월 29일',
#  '데일 카네기| 현대지성| 2019년 10월 07일',
#  '이치조 미사키| 모모| 2021년 06월 28일',
#  '오은영| 코리아닷컴| 2019년 01월 10일',
#  '김지수저자 더보기이어령| 열림원| 2021년 10월 28일',
#  '엠제이 드마코| 토트| 2022년 02월 04일',
#  '박시연| 아울북| 2022년 07월 06일',
#  '다자이 오사무| 민음사| 2012년 04월 10일',
#  '페터 비에리| 은행나무| 2014년 10월 29일',
#  '김상현| 필름(Feelm)| 2022년 04월 20일',
#  '브라이언 헤어저자 더보기버네사 우즈| 디플롯| 2021년 07월 26일',
#  '리처드 탈러저자 더보기캐스 선스타인| 리더스북| 2022년 06월 20일',
#  '밥 프록터| 비즈니스북스| 2022년 07월 12일',
#  '설민석저자 더보기스토리박스| 단꿈아이| 2022년 05월 27일',
#  '손원평| 창비| 2022년 05월 12일',
#  '게리 켈러저자 더보기제이 파파산| 비즈니스북스| 2013년 08월 30일',
#  '김승호| 스노우폭스북스| 2020년 06월 15일',
#  '스마트튜브(김학렬)| 원앤원북스| 2022년 07월 21일',
#  'Tatsuya Endo| 학산문화사| 2022년 06월 08일',
#  '김훈| 문학동네| 2022년 06월 01일',
#  '학산문화사 편집부| 학산문화사| 2020년 08월 20일',
#  '흔한남매 (원작)저자 더보기안치현| 미래엔아이세움| 2022년 06월 08일',
#  '후안 엔리케스| 세계사| 2022년 04월 19일',
#  '데일 카네기| 현대지성| 2021년 01월 13일',
#  '너나위| 알에이치코리아| 2022년 06월 20일',
#  '가토 겐| 필름(Feelm)| 2022년 07월 15일',
#  '정태익| 리더스북| 2022년 03월 22일',
#  '비욘 나티코 린데블라드| 다산초당| 2022년 04월 18일',
#  '정선근| 언탱글링| 2021년 05월 13일',
#  '김재식| 북로망스| 2022년 05월 10일',
#  '조예은| 안전가옥| 2020년 04월 13일',
#  '김창옥| 수오서재| 2022년 07월 07일',
#  '고윤(페이서스 코리아)| 마인드셋(Mindset)| 2022년 07월 03일',
#  '남궁원| 모모북스| 2022년 07월 18일',
#  '흔한남매 (원작)저자 더보기최재훈| 미래엔아이세움| 2022년 06월 28일',
#  '조우성| 서삼독| 2022년 07월 07일',
#  '김동기| 아카넷| 2020년 11월 18일',
#  '박찬위| 하이스트| 2021년 11월 25일',
#  '최진영| 은행나무| 2015년 03월 30일',
#  'David Cho| 해커스어학연구소| 2022년 01월 10일',
#  '루리| 문학동네| 2021년 02월 03일',
#  '유발 하라리| 김영사| 2015년 11월 24일',
#  '박상영| 문학동네| 2022년 07월 20일',
#  '매트 헤이그| 인플루엔셜| 2021년 04월 28일',
#  '파울로 코엘료| 문학동네| 2022년 07월 12일',
#  '나태주| 열림원| 2022년 05월 31일',
#  'Gege Akutami| 서울미디어코믹스(서울문화사)| 2022년 06월 01일',
#  '이미예| 팩토리나인| 2021년 07월 27일',
#  '도올(김용옥)| 통나무| 2022년 08월 03일',
#  'David Cho| 해커스어학연구소| 2021년 12월 13일',
#  '김혜정| 위즈덤하우스| 2022년 01월 28일',
#  'ETS| YBM| 2018년 06월 05일',
#  '정선근| 아티잔| 2019년 10월 31일',
#  '팀 페리스| 토네이도| 2022년 06월 20일',
#  '김지혜| 팩토리나인| 2022년 05월 12일',
#  '베르나르 베르베르| 열린책들| 2022년 05월 30일',
#  '김소나| 더모던| 2021년 11월 30일',
#  '윤정주| 책읽는곰| 2022년 07월 15일',
#  '김초엽| 자이언트북스| 2021년 08월 18일',
#  '김재원| 빅피시| 2022년 06월 15일',
#  '김리리| 비룡소| 2022년 04월 22일',
#  '서영조| 사람in| 2022년 03월 10일',
#  '미셸 자우너| 문학동네| 2022년 02월 28일',
#  '대원키즈 편집부| 대원키즈| 2021년 05월 20일',
#  '재레드 다이아몬드| 문학사상| 2005년 12월 19일',
#  '셀리| 넥서스| 2022년 07월 20일',
#  '최은영| 문학동네| 2021년 07월 27일',
#  '문요한| 해냄출판사| 2022년 06월 30일',
#  'NAOE| 서울미디어코믹스(서울문화사)| 2022년 06월 30일',
#  '정김경숙| 웅진지식하우스| 2022년 07월 08일',
#  '정보라| 아작| 2022년 04월 01일',
#  '알란 알렉산더 밀른| 피카(FIKA)| 2022년 07월 22일',
#  'ETS| YBM| 2020년 08월 20일',
#  'David Cho| 해커스어학연구소| 2022년 01월 10일',
#  '안녕달| 창비| 2015년 07월 27일',
#  '리처드 도킨스| 을유문화사| 2018년 10월 20일',
#  '임솔아저자 더보기김멜라김병운김지연김혜진| 문학동네| 2022년 04월 08일',
#  '칼 세이건| 사이언스북스| 2010년 01월 20일',
#  '정선근| 언탱글링| 2021년 04월 15일',
#  '나태주| 지혜| 2020년 11월 30일',
#  '후쿠다 신이치| 소미미디어| 2022년 07월 14일',
#  '팀 마샬| 사이| 2016년 08월 10일',
#  '한날| 파란정원| 2022년 07월 25일',
#  '이꽃님| 우리학교| 2021년 06월 07일',
#  '오빠두(전진권)| 제이펍| 2022년 02월 15일',
#  '보도 섀퍼| 토네이도| 2022년 03월 18일',
#  '하라 야스히사| 대원씨아이| 2022년 07월 31일',
#  '구도 노리코| 책읽는곰| 2022년 06월 23일',
#  '박미연| 이지북| 2022년 07월 04일',
#  'David Cho| 해커스어학연구소| 2022년 02월 21일',
#  '앤드루 피터슨| 다산책방| 2022년 06월 28일',
#  '흔한남매 (원작)저자 더보기백난도| 미래엔아이세움| 2022년 03월 03일',
#  '권민창| 마인드셋(Mindset)| 2022년 01월 21일',
#  '최종엽| 유노북스| 2021년 11월 03일',
#  '방울이TV (원작)저자 더보기김언정| 학산문화사| 2022년 06월 20일',
#  '앙드레 코스톨라니| 미래의창| 2015년 09월 30일',
#  '양귀자| 쓰다| 2013년 04월 01일',
#  '마이클 샌델| 와이즈베리| 2020년 12월 01일',
#  '이꽃님| 문학동네| 2021년 09월 24일',
#  '모건 하우절| 인플루엔셜| 2021년 01월 13일',
#  '학산문화사 편집부| 학산문화사| 2020년 10월 25일',
#  '법륜| 정토출판| 2022년 06월 30일',
#  '흔한남매 (원작)저자 더보기김언정| 미래엔아이세움| 2022년 05월 12일',
#  '히로나카 헤이스케| 김영사| 2013년 04월 11일',
#  '해커스 어학연구소| 해커스어학연구소| 2022년 01월 03일',
#  '팀 마샬| 사이| 2022년 04월 10일',
#  '사이다| 한스미디어| 2022년 07월 21일',
#  '조원재| 블랙피쉬| 2021년 12월 21일',
#  '이민경| 진풍경| 2022년 07월 01일',
#  '에이모 토울스| 현대문학| 2022년 07월 04일',
#  '김초엽| 허블| 2019년 06월 24일',
#  '오은영| 김영사| 2022년 07월 20일',
#  '아이휴먼 편집부| 아이휴먼| 2022년 02월 25일',
#  '한강| 문학동네| 2022년 05월 30일',
#  '해커스 오픽연구소| 해커스| 2021년 08월 13일',
#  '조수연| 다산어린이| 2022년 06월 27일',
#  '조한경저자 더보기김남수김민수김종민박범희| 해냄에듀| 2022년 05월 30일',
#  '웃소 (원작)저자 더보기한바리| 미래엔아이세움| 2022년 06월 23일',
#  '김미영| 아울북| 2022년 05월 25일',
#  'Aka Akasaka저자 더보기Mengo Yokoyari| 대원씨아이| 2022년 07월 31일',
#  '조우성| 서삼독| 2022년 07월 07일',
#  '최은영| 문학동네| 2019년 06월 20일',
#  '와타나베 준이치| 다산초당| 2022년 05월 27일',
#  '켈리 최| 다산북스| 2021년 11월 10일',
#  '히가시야마 아키라| 해피북스투유| 2022년 06월 22일',
#  '애나 렘키| 흐름출판| 2022년 03월 21일',
#  '잭파시(최경천)| 다산북스| 2022년 04월 19일',
#  '손원평| 창비| 2022년 07월 22일',
#  '정영욱| 부크럼| 2021년 05월 14일',
#  '삼성출판사 편집부| 삼성출판사| 2021년 07월 31일',
#  '히가시노 게이고| 현대문학| 2012년 12월 19일',
#  '임춘성| 쌤앤파커스| 2022년 07월 27일',
#  '오은영| 오은라이프사이언스| 2022년 05월 25일',
#  'David Cho| 해커스어학연구소| 2022년 02월 21일',
#  '개리 마커스| 갤리온| 2008년 11월 24일',
#  '조윤성| 시대인| 2022년 07월 05일',
#  '박문호| 김영사| 2022년 06월 30일',
#  '지나영| 다산북스| 2020년 11월 23일',
#  '올더스 헉슬리| 소담출판사| 2015년 06월 12일',
#  '손현주| 특별한서재| 2021년 10월 15일',
#  '송도수| 서울문화사| 2022년 07월 20일',
#  '민혜영(하브루타 민쌤)| 서사원| 2022년 07월 07일',
#  '조지 오웰| 소담출판사| 2021년 12월 08일',
#  '간다 마사노리| 생각지도| 2022년 06월 30일',
#  '손힘찬(오가타 마리토)| 떠오름| 2022년 04월 22일',
#  '에릭 와이너| 어크로스| 2021년 04월 28일',
#  '이즈미 마사토| 다산북스| 2020년 12월 14일',
#  '모데스토 가르시아| 중앙북스| 2022년 05월 30일',
#  '심태승| 국일증권경제연구소| 2022년 05월 31일',
#  '유선경| 앤의서재| 2022년 06월 10일',
#  '요무| 대원씨아이| 2022년 07월 31일',
#  '프리드리히 니체저자 더보기시라토리 하루히코 (엮음)| 삼호미디어| 2020년 03월 10일',
#  '마이클 샌델| 와이즈베리| 2014년 11월 20일',
#  '백희나| 책읽는곰| 2017년 03월 25일',
#  '손원평| 창비| 2017년 03월 31일',
#  '천선란| 한겨레출판사| 2022년 06월 22일',
#  '윤동주저자 더보기윤동주100년포럼 (엮음)| 스타북스| 2022년 02월 16일',
#  '황영미| 문학동네| 2019년 01월 28일',
#  '애덤 그랜트| 생각연구소| 2013년 06월 07일']
